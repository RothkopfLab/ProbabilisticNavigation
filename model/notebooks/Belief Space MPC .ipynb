# %%
import sys
sys.path.append("..")

import copy
import time
import pickle
import random


import numpy as np
import pandas as pd 
from numpy import matlib as mb
import matplotlib.pyplot as plt

#Casadi
from casadi import * 
import casadi.tools as cat

#Model 
from model import Model
from belief_space_planner import BeliefSpacePlanner
from state_estimation import * 
from model_predictive_control import *

#general utils 
from utils.helpers import normalize_angle, read_file, get_landmark_mu, get_landmark_sigma, get_heading

#logging + plotting 
from utils.logger import Logger
from utils.animation import get_SLAM_animation
from utils.live_plotting import Plotting 

#set plotting 
# %matplotlib notebook

# %% [markdown]
# # Do MPC Version

# %%
# import sys
sys.path.append("..")

from parameters import get_params
from mpc import * 


#initialize experimental parameters
experiment = 'nardini2008'


if experiment == 'nardini2008':
    params = get_params(experiment_name = 'nardini2008', trajectory_id = 'random', n_landmarks = 3, target_jitter=False)
    
if experiment == 'chen2017':
    params = get_params(experiment_name = 'chen2017', trajectory_id = 'random', n_landmarks = 3, start_position = [0,-2], target_jitter=True)
    params['start_position'] = [0,-2]
    
if experiment == 'zhao2015':
    params = get_params(experiment_name = 'zhao2015a', trajectory_id = 'random', n_landmarks = 3, target_jitter=False)


    

#choose experimental condition  
params['condition'] = 'combined' #self-motion,conflict,landmark
params['fov'] = 100

#create a model of the agen<t 
model = Model(n_landmarks = len(params['landmark_locations'] + params['pickup_locations'])//2,
              motion_limits = params['motion_limits'],
              R_diag = params['observation_cov'], 
              Q_diag = params['motion_cov'],
              R_diag_generative = params['observation_cov'],
              Q_diag_generative = params['motion_cov'], 
              V = 0.01295**2,
              V_generative = 0.01295**2,
              representation_type = 'all',
              fov = params['fov'])

#create planner 
planner = BeliefSpacePlanner(model, 
                             N = params['planning_horizon'],
                             verbose = False)

solver, opts = planner.create_solver(solver = 'ma57', 
                                     BFGS = True, 
                                     warm_start = True)

live_plot = Plotting()

x_true, mu_t, Sigma_t, obs0, obs_state, obs_belief, p, args, task, logger  = init_state(params, model, planner, solver)


mpc_iter = 0
sol = None

params['arena_limits'] = ((-8, 8), (-8, 8))


mpc = MPC(model, solver, planner, sol, params, obs0, obs_state, obs_belief, p, args, task, logger, live_plot)

# %%
# %matplotlib notebook
mpc_iter = 0
mpc.planner.reinit=True
n_iter = 0

while True:
    x_true, mu_t, Sigma_t, mpc_iter = mpc.update(x_true, mu_t, Sigma_t, mpc_iter, verbose = True)
    
    if task.task_finished:
        n_iter += 1         
        if n_iter > 10:
            break
# Out:
# initialize landmark at new position
# initialize landmark at new position
# initialize landmark at new position
# <img src="data:image/png;base64,..." width="1000">
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# goal reached
# waiting for next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# waiting for next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# waiting for next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# waiting for next goal
# next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# goal reached
# waiting for next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# waiting for next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# waiting for next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# waiting for next goal
# next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# goal reached
# 0.0
# waiting
# 0.1
# waiting
# 0.2
# waiting
# 0.30000000000000004
# waiting
# 0.4
# waiting
# 0.5
# waiting
# 0.6
# waiting
# 0.7
# waiting
# 0.7999999999999999
# waiting
# 0.8999999999999999
# waiting
# 0.9999999999999999
# waiting
# 1.0999999999999999
# waiting
# 1.2
# waiting
# 1.3
# waiting
# 1.4000000000000001
# waiting
# 1.5000000000000002
# waiting
# 1.6000000000000003
# waiting
# 1.7000000000000004
# waiting
# 1.8000000000000005
# waiting
# 1.9000000000000006
# waiting
# 2.0000000000000004
# waiting
# 2.1000000000000005
# waiting
# 2.2000000000000006
# waiting
# 2.3000000000000007
# waiting
# 2.400000000000001
# waiting
# 2.500000000000001
# waiting
# 2.600000000000001
# waiting
# 2.700000000000001
# waiting
# 2.800000000000001
# waiting
# 2.9000000000000012
# waiting
# 3.0000000000000013
# waiting
# 3.1000000000000014
# waiting
# 3.2000000000000015
# waiting
# 3.3000000000000016
# waiting
# 3.4000000000000017
# waiting
# 3.5000000000000018
# waiting
# 3.600000000000002
# waiting
# 3.700000000000002
# waiting
# 3.800000000000002
# waiting
# 3.900000000000002
# waiting
# 4.000000000000002
# waiting
# 4.100000000000001
# waiting
# 4.200000000000001
# waiting
# 4.300000000000001
# waiting
# 4.4
# waiting
# 4.5
# waiting
# 4.6
# waiting
# 4.699999999999999
# waiting
# 4.799999999999999
# waiting
# 4.899999999999999
# waiting
# 4.999999999999998
# waiting
# 5.099999999999998
# waiting
# 5.1999999999999975
# waiting
# 5.299999999999997
# waiting
# 5.399999999999997
# waiting
# 5.4999999999999964
# waiting
# 5.599999999999996
# waiting
# 5.699999999999996
# waiting
# 5.799999999999995
# waiting
# 5.899999999999995
# waiting
# 5.999999999999995
# waiting
# 6.099999999999994
# waiting
# 6.199999999999994
# waiting
# 6.299999999999994
# waiting
# 6.399999999999993
# waiting
# 6.499999999999993
# waiting
# 6.5999999999999925
# waiting
# 6.699999999999992
# waiting
# 6.799999999999992
# waiting
# 6.8999999999999915
# waiting
# 6.999999999999991
# waiting
# 7.099999999999991
# waiting
# 7.19999999999999
# waiting
# 7.29999999999999
# waiting
# 7.39999999999999
# waiting
# 7.499999999999989
# waiting
# 7.599999999999989
# waiting
# 7.699999999999989
# waiting
# 7.799999999999988
# waiting
# 7.899999999999988
# waiting
# 7.999999999999988
# waiting
# waiting for next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# waiting for next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# waiting for next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# waiting for next goal
# next goal
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# task finished
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
# Failed to load 'libmetis.so' - using fallback AMD code
